# %%
from IPython.display import Image

# %% [markdown]
# # Python Operators

# %% [markdown]
# ## Comparison and Logical Operators in Python

# %% [markdown]
# The comparison operators returns a boolean either True or False.
#
# Operations definitions are also given in following table:

# %%
Image(filename=r'py_course_imgs\py_operators.jpg')

# %%
x=10; y=20; i='first'; j='second'

# %%
x>y
# Out:
# False

# %%
x<y
# Out:
# True

# %%
i<j
# Out:
# True

# %%
i>j
# Out:
# False

# %%
i==j
# Out:
# False

# %%
i="second"

# %%
i==j
# Out:
# True

# %%
'hello'=='Hello'
# Out:
# False

# %%
str.upper('hello')==str.upper('Hello')
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
x>=y
# Out:
# False

# %%
x<=y
# Out:
# True

# %% [markdown]
# ## Logical Operators in Python

# %% [markdown]
# The following keywords in Python combine two Boolean expressions. They are called logical operators. Two operands should have Boolean value True or False

# %%
Image(filename=r'py_course_imgs\log_operators.jpg')

# %%
x=True; y=False

# %%
x and y
# Out:
# False

# %%
x or y
# Out:
# True

# %%
x and not y
# Out:
# True

# %%
not (x and y)
# Out:
# True
